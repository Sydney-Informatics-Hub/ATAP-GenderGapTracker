# %% [markdown]
# # Quote Extractor
# The below code can be used to extract quotes from your text.

# %%
# import the necessary packages
import pandas as pd
import os
import sys
import logging
import spacy
from nltk import Tree
from config import config
import utils

# import the quote extractor
from quote_extractor import extract_quotes, get_rawtext_files

# %%
# download spacy's en_core_web_lg
print("Loading spaCy language model...")
nlp = spacy.load('en_core_web_lg')
print("Finished loading")

# %%
# enter the file path of the file you wish to extract quotes from
file_path = './input/'
file_name = 'text_file_list.xlsx'

# read the pandas dataframe
text_df = pd.read_excel(file_path + file_name, index_col=0)
text_df
# Out:
#       text_files
# index
# 0      test1.txt
# 1      test2.txt

# %%
# specify whether to create a parse tree for the quotes and specify the file path if 'True'
write_quote_trees_in_file = False
tree_dir = './output/'

for input_file in get_rawtext_files(file_path):
    doc_id = input_file.replace(".txt", "")
    
    try:
        doc_lines = open(os.path.join(file_path, input_file), 'r').readlines()
        doc_lines = [line.rstrip() for line in doc_lines if line!='\n']
        doc_text = '\n'.join(doc_lines)
        doc_text = utils.preprocess_text(doc_text)
        doc = nlp(doc_text)
        quotes = extract_quotes(doc_id=doc_id, doc=doc, write_tree=write_quote_trees_in_file, tree_dir=tree_dir)
            
    except:
        app_logger.exception("message")
        traceback.print_exc()

# %%
# generate preview of the quotes
for n, q in enumerate(quotes[:3]):
    print('Quote number:',n)
    for key, value in q.items():
        print(key.title() + ': ' + str(value))
    print('-' * 50)
# Out:
# Quote number: 0
# Speaker: Facebook and Instagram, which Facebook owns
# Speaker_Index: (0,43)
# Quote: that Trump wouldn't be able to post for 24 hours following two violations of its policies
# Quote_Index: (84,173)
# Verb: announcing
# Verb_Index: (73,83)
# Quote_Token_Count: 17
# Quote_Type: SVC
# Is_Floating_Quote: False
# --------------------------------------------------
# Quote number: 1
# Speaker: experts
# Speaker_Index: (289,296)
# Quote: that these actions follow years of hemming and hawing regarding Trump and his supporters spreading dangerous misinformation and encouraging violence that contributed to Wednesday's events
# Quote_Index: (303,490)
# Verb: noted
# Verb_Index: (297,302)
# Quote_Token_Count: 26
# Quote_Type: SVC
# Is_Floating_Quote: False
# --------------------------------------------------
# Quote number: 2
# Speaker: Jennifer Grygiel, a Syracuse University communications professor and an expert on social media,
# Speaker_Index: (493,588)
# Quote: what happened in Washington, D.C.
# Quote_Index: (594,627)
# Verb: said
# Verb_Index: (589,593)
# Quote_Token_Count: 6
# Quote_Type: SVC
# Is_Floating_Quote: False
# --------------------------------------------------

# %%
# generate the outcome in a pandas dataframe
quotes_df = pd.DataFrame.from_dict(quotes)
quotes_df
# Out:
#     is_floating_quote                                              quote  \
# 0               False  that Trump wouldn't be able to post for 24 hou...
# 1               False  that these actions follow years of hemming and...
# 2               False                  what happened in Washington, D.C.
# 3               False  , on Wednesday is a direct result of Trump's u...
# 4               False                              This is what happens,
# 5               False      They're creeping along towards firmer action,
# 6               False  that the video was removed because it "contrib...
# 7               False  This is an emergency situation and we are taki...
# 8               False                                  "I know your pain
# 9               False      "We can't play into the hands of these people
# 10              False  The President has promoted sedition and incite...
# 11              False  there would be an "orderly transition on Janua...
# 12              False             it "doesn’t seem to pass the pub test"
# 13               True  "We didn't just see a breach at the Capitol.So...
# 14               True  "Social media is complicit in this because he ...
# 15               True  "More than anything, what is happening right n...
#
#     quote_index  quote_token_count quote_type  \
# 0      (84,173)                 17        SVC
# 1     (303,490)                 26        SVC
# 2     (594,627)                  6        SVC
# 3     (627,815)                 32        SVC
# 4   (1018,1039)                  5      QCQSV
# 5   (1358,1403)                  8      QCQSV
# 6   (2373,2478)                 18        SVC
# 7   (2484,2607)                 19      QCQSV
# 8   (2817,2834)                  5        SVC
# 9   (2979,3024)                 11        SVC
# 10  (3791,3847)                  8      QCQVS
# 11  (4164,4218)                 11        SVC
# 12  (4676,4714)                 11        SVC
# 13  (1055,1244)                 40        QCQ
# 14  (1498,1700)                 41        QCQ
# 15  (3947,4120)                 35        QCQ
#
#                                               speaker speaker_index  \
# 0         Facebook and Instagram, which Facebook owns        (0,43)
# 1                                             experts     (289,296)
# 2   Jennifer Grygiel, a Syracuse University commun...     (493,588)
# 3   Jennifer Grygiel, a Syracuse University commun...     (493,588)
# 4                                           " Grygiel   (1039,1048)
# 5                                           " Grygiel   (1403,1412)
# 6   Guy Rosen, Facebook's vice-president of integrity   (2296,2345)
# 7                                               Rosen   (2610,2615)
# 8                                               Trump   (2786,2791)
# 9                                               Trump   (2957,2962)
# 10  Jonathan Greenblatt, chief executive officer o...   (3855,3930)
# 11                                              Trump   (4153,4158)
# 12                                        the Premier   (4659,4670)
# 13                                          " Grygiel   (1039,1048)
# 14                                          " Grygiel   (1403,1412)
# 15  Jonathan Greenblatt, chief executive officer o...   (3855,3930)
#
#           verb   verb_index
# 0   announcing      (73,83)
# 1        noted    (297,302)
# 2         said    (589,593)
# 3         said    (589,593)
# 4         said  (1049,1053)
# 5         said  (1413,1417)
# 6         said  (2347,2351)
# 7         said  (2616,2620)
# 8       saying  (2809,2815)
# 9          say  (2974,2977)
# 10        said  (3850,3854)
# 11        said  (4159,4163)
# 12        said  (4671,4675)
# 13
# 14
# 15

# %%
# save the above dataframe into excel
quotes_df.to_excel('./output/quotes.xlsx', index=False)
