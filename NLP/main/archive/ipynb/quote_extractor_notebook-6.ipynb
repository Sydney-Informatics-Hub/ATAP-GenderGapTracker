# %% [markdown]
# # Quote Extractor
# In this notebook, we will use the *Quote Extractor* tool to extract quotes from a list of texts. In addition to the quote, the tool also provides some useful information such as who the speaker is, the location of the quote (and the speaker) within the text, the length of the quote, etc.

# %% [markdown]
# ## 1. Setup
# Before we begin, we need to import the necessary tools and packages for our tool to run.

# %%
# import the necessary packages
import os
import sys
import logging
import traceback

# pandas: tools for data processing
import pandas as pd

# spaCy and NLTK: natural language processing tools for working with human language data
import spacy
import nltk
nltk.download('punkt')
from nltk import Tree
from nltk.tokenize import sent_tokenize

# import the quote extractor tool
from quote_extractor import extract_quotes, get_rawtext_files
from config import config
import utils

# initiate the app_logger
app_logger = utils.create_logger('quote_extractor', log_dir='logs', logger_level=logging.INFO, 
                                 file_log_level=logging.INFO)
# Out:
# [nltk_data] Downloading package punkt to /Users/sjuf9909/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# download spaCy's en_core_web_lg, the pre-trained English language pipeline tool from spaCy
print("Loading spaCy language model...")
nlp = spacy.load('en_core_web_lg')
print("Finished loading")
# Out:
# Loading spaCy language model...
# Finished loading

# %% [markdown]
# ## 2. Load the data
# You can extract quotes from one text file (.txt file) or from many text files, at the same time, if you wish. All you need to do is to store all your text files in an input folder, and list the text file names on an excel spreadsheet.

# %%
# enter the file path and the file name of the excel spreadsheet containing the list of texts
# please ensure that the text files (.txt) are stored in the same folder
file_path = './input/'
file_name = 'text_files.xlsx'

# read the pandas dataframe containing the list of texts
text_df = pd.read_excel(file_path + file_name, index_col=0)
text_df.head()
# Out:
#                                                    texts description
# index
# 0      Facebook and Instagram, which Facebook owns, f...      random
# 1      (CBC News)\nRepublican lawmakers and previous ...    CBC news

# %%
tt = text_df['texts'][0]

# %%
# specify whether you wish to create a parse tree for the quotes and specify the file path if 'True'
write_quote_trees_in_file = False
tree_dir = './output/trees/'

# begin to extract quotes from your text files
all_quotes = []
for n, text in enumerate(text_df['texts']):
    doc_id = 'text' + str(n)
    
    try:
        text = sent_tokenize(text)
        text = " ".join(text)
        text = utils.preprocess_text(text)
        doc = nlp(text)
        quotes = extract_quotes(doc_id=doc_id, doc=doc, 
                                write_tree=write_quote_trees_in_file, 
                                tree_dir=tree_dir)
        
        for n, quote in enumerate(quotes):
            quote['quote_id']=doc_id + '-' + str(n+1)
        all_quotes.extend(quotes)
            
    except:
        app_logger.exception("message")
        traceback.print_exc()

# %%
# generate a preview of the quotes
for n, q in enumerate(all_quotes):
    print('Quote number:',n)
    for key, value in q.items():
        print(key.title() + ': ' + str(value))
    print('-' * 120)
# Out:
# Quote number: 0
# Speaker: Grygiel
# Speaker_Index: (1239,1246)
# Quote: "We didn't just see a breach at the Capitol. Social media platforms have been breached by the president repeatedly. This is disinformation. This was a coup attempt in the United States."
# Quote_Index: (1052,1238)
# Verb: said
# Verb_Index: (1247,1251)
# Quote_Token_Count: 38
# Quote_Type: Heuristic
# Is_Floating_Quote: False
# Quote_Id: text0-1
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 1
# Speaker: Facebook and Instagram, which Facebook owns
# Speaker_Index: (0,43)
# Quote: that Trump wouldn't be able to post for 24 hours following two violations of its policies
# Quote_Index: (84,173)
# Verb: announcing
# Verb_Index: (73,83)
# Quote_Token_Count: 17
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: text0-2
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 2
# Speaker: experts
# Speaker_Index: (288,295)
# Quote: that these actions follow years of hemming and hawing regarding Trump and his supporters spreading dangerous misinformation and encouraging violence that contributed to Wednesday's events
# Quote_Index: (302,489)
# Verb: noted
# Verb_Index: (296,301)
# Quote_Token_Count: 26
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: text0-3
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 3
# Speaker: Jennifer Grygiel, a Syracuse University communications professor and an expert on social media,
# Speaker_Index: (491,586)
# Quote: what happened in Washington, D.C.
# Quote_Index: (592,625)
# Verb: said
# Verb_Index: (587,591)
# Quote_Token_Count: 6
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: text0-4
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 4
# Speaker: Jennifer Grygiel, a Syracuse University communications professor and an expert on social media,
# Speaker_Index: (491,586)
# Quote: , on Wednesday is a direct result of Trump's use of social media to spread propaganda and disinformation, and that the platforms should bear some responsibility for their previous inaction
# Quote_Index: (625,813)
# Verb: said
# Verb_Index: (587,591)
# Quote_Token_Count: 32
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: text0-5
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 5
# Speaker: " Grygiel
# Speaker_Index: (1036,1045)
# Quote: This is what happens,
# Quote_Index: (1015,1036)
# Verb: said
# Verb_Index: (1046,1050)
# Quote_Token_Count: 5
# Quote_Type: QCQSV
# Is_Floating_Quote: False
# Quote_Id: text0-6
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 6
# Speaker: " Grygiel
# Speaker_Index: (1397,1406)
# Quote: They're creeping along towards firmer action,
# Quote_Index: (1352,1397)
# Verb: said
# Verb_Index: (1407,1411)
# Quote_Token_Count: 8
# Quote_Type: QCQSV
# Is_Floating_Quote: False
# Quote_Id: text0-7
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 7
# Speaker: Guy Rosen, Facebook's vice-president of integrity
# Speaker_Index: (2285,2334)
# Quote: that the video was removed because it "contributes to rather than diminishes the risk of ongoing violence
# Quote_Index: (2362,2467)
# Verb: said
# Verb_Index: (2336,2340)
# Quote_Token_Count: 18
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: text0-8
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 8
# Speaker: Rosen
# Speaker_Index: (2597,2602)
# Quote: "This is an emergency situation and we are taking appropriate emergency measures, including removing President Trump's video
# Quote_Index: (2470,2594)
# Verb: said
# Verb_Index: (2603,2607)
# Quote_Token_Count: 20
# Quote_Type: QCQSV
# Is_Floating_Quote: False
# Quote_Id: text0-9
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 9
# Speaker: Trump
# Speaker_Index: (2771,2776)
# Quote: "I know your pain
# Quote_Index: (2802,2819)
# Verb: saying
# Verb_Index: (2794,2800)
# Quote_Token_Count: 5
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: text0-10
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 10
# Speaker: Trump
# Speaker_Index: (2940,2945)
# Quote: "We can't play into the hands of these people
# Quote_Index: (2962,3007)
# Verb: say
# Verb_Index: (2957,2960)
# Quote_Token_Count: 11
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: text0-11
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 11
# Speaker: " Grygiel
# Speaker_Index: (1397,1406)
# Quote: "Social media is complicit in this because he has repeatedly used social media to incite violence.It's a culmination of years of propaganda and abuse of media by the president of the United States."
# Quote_Index: (1492,1691)
# Verb:
# Verb_Index:
# Quote_Token_Count: 39
# Quote_Type: QCQ
# Is_Floating_Quote: True
# Quote_Id: text0-12
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 12
# Speaker: Jonathan Greenblatt, chief executive officer of the Anti-Defamation League,
# Speaker_Index: (755,830)
# Quote: The President has promoted sedition and incited violence
# Quote_Index: (691,747)
# Verb: said
# Verb_Index: (750,754)
# Quote_Token_Count: 8
# Quote_Type: QCQVS
# Is_Floating_Quote: False
# Quote_Id: text1-1
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 13
# Speaker: Trump
# Speaker_Index: (1051,1056)
# Quote: there would be an "orderly transition on January 20th"
# Quote_Index: (1062,1116)
# Verb: said
# Verb_Index: (1057,1061)
# Quote_Token_Count: 11
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: text1-2
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 14
# Speaker: the Premier
# Speaker_Index: (1556,1567)
# Quote: it "doesn’t seem to pass the pub test"
# Quote_Index: (1573,1611)
# Verb: said
# Verb_Index: (1568,1572)
# Quote_Token_Count: 11
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: text1-3
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 15
# Speaker: Jonathan Greenblatt, chief executive officer of the Anti-Defamation League,
# Speaker_Index: (755,830)
# Quote: "More than anything, what is happening right now at the Capitol is a direct result of the fear and disinformation that has been spewed consistently from the Oval Office."
# Quote_Index: (847,1017)
# Verb:
# Verb_Index:
# Quote_Token_Count: 33
# Quote_Type: QCQ
# Is_Floating_Quote: True
# Quote_Id: text1-4
# ------------------------------------------------------------------------------------------------------------------------

# %%
# specify whether you wish to create a parse tree for the quotes and specify the file path if 'True'
write_quote_trees_in_file = False
tree_dir = './output/trees/'

# begin to extract quotes from your text files
all_quotes = []
for input_file in get_rawtext_files(file_path):
    doc_id = input_file.replace(".txt", "")
    
    try:
        doc_lines = open(os.path.join(file_path, input_file), 'r').readlines()
        #print(doc_lines)
        doc_lines = [line.rstrip() for line in doc_lines if line!='\n']
        #print(doc_lines)
        doc_text = '\n'.join(doc_lines)
        doc_text = utils.preprocess_text(doc_text)
        doc = nlp(doc_text)
        quotes = extract_quotes(doc_id=doc_id, doc=doc, write_tree=write_quote_trees_in_file, tree_dir=tree_dir)
        for n, quote in enumerate(quotes):
            quote['quote_id']=doc_id + '-' + str(n+1)
        all_quotes.extend(quotes)
            
    except:
        app_logger.exception("message")
        traceback.print_exc()

# %%
# generate a preview of the quotes
for n, q in enumerate(all_quotes):
    print('Quote number:',n)
    for key, value in q.items():
        print(key.title() + ': ' + str(value))
    print('-' * 120)
# Out:
# Quote number: 0
# Speaker: Facebook and Instagram, which Facebook owns
# Speaker_Index: (0,43)
# Quote: that Trump wouldn't be able to post for 24 hours following two violations of its policies
# Quote_Index: (84,173)
# Verb: announcing
# Verb_Index: (73,83)
# Quote_Token_Count: 17
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: test1-1
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 1
# Speaker: experts
# Speaker_Index: (289,296)
# Quote: that these actions follow years of hemming and hawing regarding Trump and his supporters spreading dangerous misinformation and encouraging violence that contributed to Wednesday's events
# Quote_Index: (303,490)
# Verb: noted
# Verb_Index: (297,302)
# Quote_Token_Count: 26
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: test1-2
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 2
# Speaker: Jennifer Grygiel, a Syracuse University communications professor and an expert on social media,
# Speaker_Index: (493,588)
# Quote: what happened in Washington, D.C.
# Quote_Index: (594,627)
# Verb: said
# Verb_Index: (589,593)
# Quote_Token_Count: 6
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: test1-3
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 3
# Speaker: Jennifer Grygiel, a Syracuse University communications professor and an expert on social media,
# Speaker_Index: (493,588)
# Quote: , on Wednesday is a direct result of Trump's use of social media to spread propaganda and disinformation, and that the platforms should bear some responsibility for their previous inaction
# Quote_Index: (627,815)
# Verb: said
# Verb_Index: (589,593)
# Quote_Token_Count: 32
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: test1-4
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 4
# Speaker: " Grygiel
# Speaker_Index: (1039,1048)
# Quote: This is what happens,
# Quote_Index: (1018,1039)
# Verb: said
# Verb_Index: (1049,1053)
# Quote_Token_Count: 5
# Quote_Type: QCQSV
# Is_Floating_Quote: False
# Quote_Id: test1-5
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 5
# Speaker: " Grygiel
# Speaker_Index: (1403,1412)
# Quote: They're creeping along towards firmer action,
# Quote_Index: (1358,1403)
# Verb: said
# Verb_Index: (1413,1417)
# Quote_Token_Count: 8
# Quote_Type: QCQSV
# Is_Floating_Quote: False
# Quote_Id: test1-6
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 6
# Speaker: Guy Rosen, Facebook's vice-president of integrity
# Speaker_Index: (2296,2345)
# Quote: that the video was removed because it "contributes to rather than diminishes the risk of ongoing violence
# Quote_Index: (2373,2478)
# Verb: said
# Verb_Index: (2347,2351)
# Quote_Token_Count: 18
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: test1-7
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 7
# Speaker: Rosen
# Speaker_Index: (2610,2615)
# Quote: This is an emergency situation and we are taking appropriate emergency measures, including removing President Trump's video
# Quote_Index: (2484,2607)
# Verb: said
# Verb_Index: (2616,2620)
# Quote_Token_Count: 19
# Quote_Type: QCQSV
# Is_Floating_Quote: False
# Quote_Id: test1-8
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 8
# Speaker: Trump
# Speaker_Index: (2786,2791)
# Quote: "I know your pain
# Quote_Index: (2817,2834)
# Verb: saying
# Verb_Index: (2809,2815)
# Quote_Token_Count: 5
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: test1-9
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 9
# Speaker: Trump
# Speaker_Index: (2957,2962)
# Quote: "We can't play into the hands of these people
# Quote_Index: (2979,3024)
# Verb: say
# Verb_Index: (2974,2977)
# Quote_Token_Count: 11
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: test1-10
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 10
# Speaker: " Grygiel
# Speaker_Index: (1039,1048)
# Quote: "We didn't just see a breach at the Capitol.Social media platforms have been breached by the president repeatedly.This is disinformation.This was a coup attempt in the United States.".
#
# Quote_Index: (1055,1244)
# Verb:
# Verb_Index:
# Quote_Token_Count: 40
# Quote_Type: QCQ
# Is_Floating_Quote: True
# Quote_Id: test1-11
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 11
# Speaker: " Grygiel
# Speaker_Index: (1403,1412)
# Quote: "Social media is complicit in this because he has repeatedly used social media to incite violence.It's a culmination of years of propaganda and abuse of media by the president of the United States.".
#
# Quote_Index: (1498,1700)
# Verb:
# Verb_Index:
# Quote_Token_Count: 41
# Quote_Type: QCQ
# Is_Floating_Quote: True
# Quote_Id: test1-12
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 12
# Speaker: Jonathan Greenblatt, chief executive officer of the Anti-Defamation League,
# Speaker_Index: (757,832)
# Quote: The President has promoted sedition and incited violence
# Quote_Index: (693,749)
# Verb: said
# Verb_Index: (752,756)
# Quote_Token_Count: 8
# Quote_Type: QCQVS
# Is_Floating_Quote: False
# Quote_Id: test2-1
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 13
# Speaker: Trump
# Speaker_Index: (1055,1060)
# Quote: there would be an "orderly transition on January 20th"
# Quote_Index: (1066,1120)
# Verb: said
# Verb_Index: (1061,1065)
# Quote_Token_Count: 11
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: test2-2
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 14
# Speaker: the Premier
# Speaker_Index: (1561,1572)
# Quote: it "doesn’t seem to pass the pub test"
# Quote_Index: (1578,1616)
# Verb: said
# Verb_Index: (1573,1577)
# Quote_Token_Count: 11
# Quote_Type: SVC
# Is_Floating_Quote: False
# Quote_Id: test2-3
# ------------------------------------------------------------------------------------------------------------------------
# Quote number: 15
# Speaker: Jonathan Greenblatt, chief executive officer of the Anti-Defamation League,
# Speaker_Index: (757,832)
# Quote: "More than anything, what is happening right now at the Capitol is a direct result of the fear and disinformation that has been spewed consistently from the Oval Office.".
#
# Quote_Index: (849,1022)
# Verb:
# Verb_Index:
# Quote_Token_Count: 35
# Quote_Type: QCQ
# Is_Floating_Quote: True
# Quote_Id: test2-4
# ------------------------------------------------------------------------------------------------------------------------

# %%
# generate the outcome in a pandas dataframe
quotes_df = pd.DataFrame.from_dict(all_quotes)
new_index = ['quote_id', 'quote', 'quote_index', 'quote_token_count', 'quote_type','is_floating_quote', 
             'speaker', 'speaker_index', 'verb', 'verb_index']
quotes_df = quotes_df.reindex(columns=new_index)
quotes_df.head()
# Out:
#   quote_id                                              quote  quote_index  \
# 0  test1-1  that Trump wouldn't be able to post for 24 hou...     (84,173)
# 1  test1-2  that these actions follow years of hemming and...    (303,490)
# 2  test1-3                  what happened in Washington, D.C.    (594,627)
# 3  test1-4  , on Wednesday is a direct result of Trump's u...    (627,815)
# 4  test1-5                              This is what happens,  (1018,1039)
#
#    quote_token_count quote_type  is_floating_quote  \
# 0                 17        SVC              False
# 1                 26        SVC              False
# 2                  6        SVC              False
# 3                 32        SVC              False
# 4                  5      QCQSV              False
#
#                                              speaker speaker_index  \
# 0        Facebook and Instagram, which Facebook owns        (0,43)
# 1                                            experts     (289,296)
# 2  Jennifer Grygiel, a Syracuse University commun...     (493,588)
# 3  Jennifer Grygiel, a Syracuse University commun...     (493,588)
# 4                                          " Grygiel   (1039,1048)
#
#          verb   verb_index
# 0  announcing      (73,83)
# 1       noted    (297,302)
# 2        said    (589,593)
# 3        said    (589,593)
# 4        said  (1049,1053)

# %%
quotes_df
# Out:
#     quote_id                                              quote  quote_index  \
# 0    test1-1  that Trump wouldn't be able to post for 24 hou...     (84,173)
# 1    test1-2  that these actions follow years of hemming and...    (303,490)
# 2    test1-3                  what happened in Washington, D.C.    (594,627)
# 3    test1-4  , on Wednesday is a direct result of Trump's u...    (627,815)
# 4    test1-5                              This is what happens,  (1018,1039)
# 5    test1-6      They're creeping along towards firmer action,  (1358,1403)
# 6    test1-7  that the video was removed because it "contrib...  (2373,2478)
# 7    test1-8  This is an emergency situation and we are taki...  (2484,2607)
# 8    test1-9                                  "I know your pain  (2817,2834)
# 9   test1-10      "We can't play into the hands of these people  (2979,3024)
# 10  test1-11  "We didn't just see a breach at the Capitol.So...  (1055,1244)
# 11  test1-12  "Social media is complicit in this because he ...  (1498,1700)
# 12   test2-1  The President has promoted sedition and incite...    (693,749)
# 13   test2-2  there would be an "orderly transition on Janua...  (1066,1120)
# 14   test2-3             it "doesn’t seem to pass the pub test"  (1578,1616)
# 15   test2-4  "More than anything, what is happening right n...   (849,1022)
#
#     quote_token_count quote_type  is_floating_quote  \
# 0                  17        SVC              False
# 1                  26        SVC              False
# 2                   6        SVC              False
# 3                  32        SVC              False
# 4                   5      QCQSV              False
# 5                   8      QCQSV              False
# 6                  18        SVC              False
# 7                  19      QCQSV              False
# 8                   5        SVC              False
# 9                  11        SVC              False
# 10                 40        QCQ               True
# 11                 41        QCQ               True
# 12                  8      QCQVS              False
# 13                 11        SVC              False
# 14                 11        SVC              False
# 15                 35        QCQ               True
#
#                                               speaker speaker_index  \
# 0         Facebook and Instagram, which Facebook owns        (0,43)
# 1                                             experts     (289,296)
# 2   Jennifer Grygiel, a Syracuse University commun...     (493,588)
# 3   Jennifer Grygiel, a Syracuse University commun...     (493,588)
# 4                                           " Grygiel   (1039,1048)
# 5                                           " Grygiel   (1403,1412)
# 6   Guy Rosen, Facebook's vice-president of integrity   (2296,2345)
# 7                                               Rosen   (2610,2615)
# 8                                               Trump   (2786,2791)
# 9                                               Trump   (2957,2962)
# 10                                          " Grygiel   (1039,1048)
# 11                                          " Grygiel   (1403,1412)
# 12  Jonathan Greenblatt, chief executive officer o...     (757,832)
# 13                                              Trump   (1055,1060)
# 14                                        the Premier   (1561,1572)
# 15  Jonathan Greenblatt, chief executive officer o...     (757,832)
#
#           verb   verb_index
# 0   announcing      (73,83)
# 1        noted    (297,302)
# 2         said    (589,593)
# 3         said    (589,593)
# 4         said  (1049,1053)
# 5         said  (1413,1417)
# 6         said  (2347,2351)
# 7         said  (2616,2620)
# 8       saying  (2809,2815)
# 9          say  (2974,2977)
# 10
# 11
# 12        said    (752,756)
# 13        said  (1061,1065)
# 14        said  (1573,1577)
# 15

# %%
# save the above dataframe into excel
quotes_df.to_excel('./output/quotes.xlsx', index=False)
