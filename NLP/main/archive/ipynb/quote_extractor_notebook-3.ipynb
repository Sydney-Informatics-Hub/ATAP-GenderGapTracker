# %% [markdown]
# # Quote Extractor
# The below code can be used to extract quotes from your text.

# %%
# import the necessary packages
import pandas as pd
import os
import sys
import logging
import traceback
import spacy
from nltk import Tree


# import the quote extractor
from quote_extractor import extract_quotes, get_rawtext_files
from config import config
import utils

# %%
# download spacy's en_core_web_lg
print("Loading spaCy language model...")
nlp = spacy.load('en_core_web_lg')
print("Finished loading")
# Out:
# Loading spaCy language model...
# Finished loading

# %%
# enter the file path and the file name containing the list of texts you wish to extract the quote from
# please ensure that the .txt files are located in the same path
file_path = './input/'
file_name = 'text_file_list.xlsx'

# read the pandas dataframe containing the list of texts
text_df = pd.read_excel(file_path + file_name, index_col=0)
text_df.head()
# Out:
#       text_files description
# index
# 0      test1.txt      random
# 1      test2.txt    CBC news

# %%
# specify whether you wish to create a parse tree for the quotes and specify the file path if 'True'
write_quote_trees_in_file = False
tree_dir = './output/'

all_quotes = []
for input_file in text_df['text_files']:
    doc_id = input_file.replace(".txt", "")
    
    try:
        doc_lines = open(os.path.join(file_path, input_file), 'r').readlines()
        doc_lines = [line.rstrip() for line in doc_lines if line!='\n']
        doc_text = '\n'.join(doc_lines)
        doc_text = utils.preprocess_text(doc_text)
        doc = nlp(doc_text)
        quotes = extract_quotes(doc_id=doc_id, doc=doc, write_tree=write_quote_trees_in_file, tree_dir=tree_dir)
        for quote in quotes:
            quote['doc_id']=doc_id
        all_quotes.extend(quotes)
            
    except:
        app_logger.exception("message")
        traceback.print_exc()

# %%
# generate preview of the quotes
for n, q in enumerate(all_quotes[:3]):
    print('Quote number:',n)
    for key, value in q.items():
        print(key.title() + ': ' + str(value))
    print('-' * 50)
# Out:
# Quote number: 0
# Speaker: Facebook and Instagram, which Facebook owns
# Speaker_Index: (0,43)
# Quote: that Trump wouldn't be able to post for 24 hours following two violations of its policies
# Quote_Index: (84,173)
# Verb: announcing
# Verb_Index: (73,83)
# Quote_Token_Count: 17
# Quote_Type: SVC
# Is_Floating_Quote: False
# Doc_Id: test1
# --------------------------------------------------
# Quote number: 1
# Speaker: experts
# Speaker_Index: (289,296)
# Quote: that these actions follow years of hemming and hawing regarding Trump and his supporters spreading dangerous misinformation and encouraging violence that contributed to Wednesday's events
# Quote_Index: (303,490)
# Verb: noted
# Verb_Index: (297,302)
# Quote_Token_Count: 26
# Quote_Type: SVC
# Is_Floating_Quote: False
# Doc_Id: test1
# --------------------------------------------------
# Quote number: 2
# Speaker: Jennifer Grygiel, a Syracuse University communications professor and an expert on social media,
# Speaker_Index: (493,588)
# Quote: what happened in Washington, D.C.
# Quote_Index: (594,627)
# Verb: said
# Verb_Index: (589,593)
# Quote_Token_Count: 6
# Quote_Type: SVC
# Is_Floating_Quote: False
# Doc_Id: test1
# --------------------------------------------------

# %%
list(quotes_df.columns)
# Out:
# ['doc_id',
#  'is_floating_quote',
#  'quote',
#  'quote_index',
#  'quote_token_count',
#  'quote_type',
#  'speaker',
#  'speaker_index',
#  'verb',
#  'verb_index']

# %%
# generate the outcome in a pandas dataframe
quotes_df = pd.DataFrame.from_dict(all_quotes)
new_index = ['quote', 'quote_index', 'quote_token_count', 'quote_type','is_floating_quote', 
             'speaker', 'speaker_index', 'verb', 'verb_index', 'doc_id']
quotes_df = quotes_df.reindex(columns=new_index)
quotes_df
# Out:
#                                                 quote  quote_index  \
# 0   that Trump wouldn't be able to post for 24 hou...     (84,173)
# 1   that these actions follow years of hemming and...    (303,490)
# 2                   what happened in Washington, D.C.    (594,627)
# 3   , on Wednesday is a direct result of Trump's u...    (627,815)
# 4                               This is what happens,  (1018,1039)
# 5       They're creeping along towards firmer action,  (1358,1403)
# 6   that the video was removed because it "contrib...  (2373,2478)
# 7   This is an emergency situation and we are taki...  (2484,2607)
# 8                                   "I know your pain  (2817,2834)
# 9       "We can't play into the hands of these people  (2979,3024)
# 10  "We didn't just see a breach at the Capitol.So...  (1055,1244)
# 11  "Social media is complicit in this because he ...  (1498,1700)
# 12  The President has promoted sedition and incite...    (693,749)
# 13  there would be an "orderly transition on Janua...  (1066,1120)
# 14             it "doesn’t seem to pass the pub test"  (1578,1616)
# 15  "More than anything, what is happening right n...   (849,1022)
#
#     quote_token_count quote_type  is_floating_quote  \
# 0                  17        SVC              False
# 1                  26        SVC              False
# 2                   6        SVC              False
# 3                  32        SVC              False
# 4                   5      QCQSV              False
# 5                   8      QCQSV              False
# 6                  18        SVC              False
# 7                  19      QCQSV              False
# 8                   5        SVC              False
# 9                  11        SVC              False
# 10                 40        QCQ               True
# 11                 41        QCQ               True
# 12                  8      QCQVS              False
# 13                 11        SVC              False
# 14                 11        SVC              False
# 15                 35        QCQ               True
#
#                                               speaker speaker_index  \
# 0         Facebook and Instagram, which Facebook owns        (0,43)
# 1                                             experts     (289,296)
# 2   Jennifer Grygiel, a Syracuse University commun...     (493,588)
# 3   Jennifer Grygiel, a Syracuse University commun...     (493,588)
# 4                                           " Grygiel   (1039,1048)
# 5                                           " Grygiel   (1403,1412)
# 6   Guy Rosen, Facebook's vice-president of integrity   (2296,2345)
# 7                                               Rosen   (2610,2615)
# 8                                               Trump   (2786,2791)
# 9                                               Trump   (2957,2962)
# 10                                          " Grygiel   (1039,1048)
# 11                                          " Grygiel   (1403,1412)
# 12  Jonathan Greenblatt, chief executive officer o...     (757,832)
# 13                                              Trump   (1055,1060)
# 14                                        the Premier   (1561,1572)
# 15  Jonathan Greenblatt, chief executive officer o...     (757,832)
#
#           verb   verb_index doc_id
# 0   announcing      (73,83)  test1
# 1        noted    (297,302)  test1
# 2         said    (589,593)  test1
# 3         said    (589,593)  test1
# 4         said  (1049,1053)  test1
# 5         said  (1413,1417)  test1
# 6         said  (2347,2351)  test1
# 7         said  (2616,2620)  test1
# 8       saying  (2809,2815)  test1
# 9          say  (2974,2977)  test1
# 10                           test1
# 11                           test1
# 12        said    (752,756)  test2
# 13        said  (1061,1065)  test2
# 14        said  (1573,1577)  test2
# 15                           test2

# %%
# specify whether to create a parse tree for the quotes and specify the file path if 'True'
write_quote_trees_in_file = False
tree_dir = './output/'

for input_file in get_rawtext_files(file_path):
    doc_id = input_file.replace(".txt", "")
    
    try:
        doc_lines = open(os.path.join(file_path, input_file), 'r').readlines()
        doc_lines = [line.rstrip() for line in doc_lines if line!='\n']
        doc_text = '\n'.join(doc_lines)
        doc_text = utils.preprocess_text(doc_text)
        doc = nlp(doc_text)
        quotes = extract_quotes(doc_id=doc_id, doc=doc, write_tree=write_quote_trees_in_file, tree_dir=tree_dir)
            
    except:
        app_logger.exception("message")
        traceback.print_exc()

# %%
# generate preview of the quotes
for n, q in enumerate(quotes[:3]):
    print('Quote number:',n)
    for key, value in q.items():
        print(key.title() + ': ' + str(value))
    print('-' * 50)
# Out:
# Quote number: 0
# Speaker: Facebook and Instagram, which Facebook owns
# Speaker_Index: (0,43)
# Quote: that Trump wouldn't be able to post for 24 hours following two violations of its policies
# Quote_Index: (84,173)
# Verb: announcing
# Verb_Index: (73,83)
# Quote_Token_Count: 17
# Quote_Type: SVC
# Is_Floating_Quote: False
# --------------------------------------------------
# Quote number: 1
# Speaker: experts
# Speaker_Index: (289,296)
# Quote: that these actions follow years of hemming and hawing regarding Trump and his supporters spreading dangerous misinformation and encouraging violence that contributed to Wednesday's events
# Quote_Index: (303,490)
# Verb: noted
# Verb_Index: (297,302)
# Quote_Token_Count: 26
# Quote_Type: SVC
# Is_Floating_Quote: False
# --------------------------------------------------
# Quote number: 2
# Speaker: Jennifer Grygiel, a Syracuse University communications professor and an expert on social media,
# Speaker_Index: (493,588)
# Quote: what happened in Washington, D.C.
# Quote_Index: (594,627)
# Verb: said
# Verb_Index: (589,593)
# Quote_Token_Count: 6
# Quote_Type: SVC
# Is_Floating_Quote: False
# --------------------------------------------------

# %%
# generate the outcome in a pandas dataframe
quotes_df = pd.DataFrame.from_dict(all_quotes)
quotes_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-c34ed6a9bfa2> in <module>
#       1 # generate the outcome in a pandas dataframe
# ----> 2 quotes_df = pd.DataFrame.from_dict(all_quotes)
#       3 quotes_df
#
# /opt/anaconda3/envs/quote/lib/python3.6/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1136             raise ValueError('only recognize index or columns for orient')
#    1137
# -> 1138         return cls(data, index=index, columns=columns, dtype=dtype)
#    1139
#    1140     def to_numpy(self, dtype=None, copy=False):
#
# /opt/anaconda3/envs/quote/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# /opt/anaconda3/envs/quote/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# /opt/anaconda3/envs/quote/lib/python3.6/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# /opt/anaconda3/envs/quote/lib/python3.6/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
# save the above dataframe into excel
quotes_df.to_excel('./output/quotes.xlsx', index=False)
